# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight")
sns.set_style('whitegrid')
# %matplotlib inline
plt.rcParams.update({'font.size': 15})

from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

from pandas_datareader.data import DataReader

from datetime import datetime
import yfinance as yf

# %%
# Set start and end time for data grab
end = '2023-12-15'
start = '2022-11-30'

NVDA = yf.download('NVDA',  start, end)
SO = yf.download('SO', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # NVDA

# %%
# Ref: Lec 17

# Create a new dataframe with only the 'Close column
NVDA = NVDA.filter(['Close'])
# Convert the dataframe to a numpy array
NVDA_dataset = NVDA.values
# Train test split
train_size_NVDA = int(np.ceil( len(NVDA_dataset) * .80 ))

train_size_NVDA
# Out:
# 210

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
NVDA_scaled = scaler.fit_transform(NVDA_dataset)

# %%
# Create scaled training data set
train_NVDA = NVDA_scaled[0:int(train_size_NVDA), :]
# Split the data into x_train and y_train data sets
x_train_NV = []
y_train_NV = []

for i in range(30, len(train_NVDA)):
    x_train_NV.append(train_NVDA[i-30:i, 0])
    y_train_NV.append(train_NVDA[i, 0])
    if i<= 31:
        print(x_train_NV)
        print(y_train_NV)
        print()

# Convert the x_train and y_train to numpy arrays
x_train_NV, y_train_NV = np.array(x_train_NV), np.array(y_train_NV)

# Reshape the data
x_train_NV = np.reshape(x_train_NV, (x_train_NV.shape[0], x_train_NV.shape[1], 1))
# Out:
# [array([0.07937205, 0.08520058, 0.07807988, 0.07076679, 0.05363867,
#        0.05729524, 0.08613533, 0.08151649, 0.09619775, 0.11096143,
#        0.10001926, 0.08016937, 0.06969457, 0.06097928, 0.05633301,
#        0.06777003, 0.03582327, 0.03216671, 0.00233692, 0.        ,
#        0.01558848, 0.0158909 , 0.00767051, 0.01960247, 0.00629586,
#        0.02262666, 0.04376873, 0.05149423, 0.05402357, 0.06804498])]
# [0.07871224594921367]
#
# [array([0.07937205, 0.08520058, 0.07807988, 0.07076679, 0.05363867,
#        0.05729524, 0.08613533, 0.08151649, 0.09619775, 0.11096143,
#        0.10001926, 0.08016937, 0.06969457, 0.06097928, 0.05633301,
#        0.06777003, 0.03582327, 0.03216671, 0.00233692, 0.        ,
#        0.01558848, 0.0158909 , 0.00767051, 0.01960247, 0.00629586,
#        0.02262666, 0.04376873, 0.05149423, 0.05402357, 0.06804498]), array([0.08520058, 0.07807988, 0.07076679, 0.05363867, 0.05729524,
#        0.08613533, 0.08151649, 0.09619775, 0.11096143, 0.10001926,
#        0.08016937, 0.06969457, 0.06097928, 0.05633301, 0.06777003,
#        0.03582327, 0.03216671, 0.00233692, 0.        , 0.01558848,
#        0.0158909 , 0.00767051, 0.01960247, 0.00629586, 0.02262666,
#        0.04376873, 0.05149423, 0.05402357, 0.06804498, 0.07871225])]
# [0.07871224594921367, 0.10078905807254468]

# %%
# Build model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train_NV.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(x_train_NV, y_train_NV, batch_size=64, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 5s 92ms/step - loss: 0.2486
# Epoch 2/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0287
# Epoch 3/50
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0308
# Epoch 4/50
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0108
# Epoch 5/50
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0224
# Epoch 6/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0121
# Epoch 7/50
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0054
# Epoch 8/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0094
# Epoch 9/50
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0068
# Epoch 10/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0046
# Epoch 11/50
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0056
# Epoch 12/50
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0048
# Epoch 13/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0036
# Epoch 14/50
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0038
# Epoch 15/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0036
# Epoch 16/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0031
# Epoch 17/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0033
# Epoch 18/50
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0032
# Epoch 19/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0030
# Epoch 20/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0031
# Epoch 21/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0031
# Epoch 22/50
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0031
# Epoch 23/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0030
# Epoch 24/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0030
# Epoch 25/50
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0030
# Epoch 26/50
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0030
# Epoch 27/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0030
# Epoch 28/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0029
# Epoch 29/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0029
# Epoch 30/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0029
# Epoch 31/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0029
# Epoch 32/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0029
# Epoch 33/50
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0029
# Epoch 34/50
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0029
# Epoch 35/50
# 3/3 [==============================] - 1s 176ms/step - loss: 0.0029
# Epoch 36/50
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0029
# Epoch 37/50
# 3/3 [==============================] - 1s 174ms/step - loss: 0.0029
# Epoch 38/50
# 3/3 [==============================] - 1s 169ms/step - loss: 0.0028
# Epoch 39/50
# 3/3 [==============================] - 0s 167ms/step - loss: 0.0029
# Epoch 40/50
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0028
# Epoch 41/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0028
# Epoch 42/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0028
# Epoch 43/50
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0028
# Epoch 44/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0028
# Epoch 45/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0028
# Epoch 46/50
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0028
# Epoch 47/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0028
# Epoch 48/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0027
# Epoch 49/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0027
# Epoch 50/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0027

# %%
plt.figure(figsize=(16,6))
plt.title('NVDA Loss Function')
plt.plot(history.history['loss'])
plt.xlabel('Epochs', fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.show()

# %%
test_data_NVDA = NVDA_scaled[train_size_NVDA - 30: , :]
# Create the data sets x_test and y_test
x_test_NVDA = []
y_test_NVDA = NVDA_dataset[train_size_NVDA:, :]
for i in range(30, len(test_data_NVDA)):
    x_test_NVDA.append(test_data_NVDA[i-30:i, 0])

# Convert the data to a numpy array
x_test_NVDA = np.array(x_test_NVDA)

# Reshape the data
x_test_NVDA = np.reshape(x_test_NVDA, (x_test_NVDA.shape[0], x_test_NVDA.shape[1], 1 ))

# Get the models predicted price values
NVDA_pred = model.predict(x_test_NVDA)
NVDA_pred = scaler.inverse_transform(NVDA_pred)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test_NVDA, NVDA_pred))

# Calculate MAE
mae = mean_absolute_error(y_test_NVDA, NVDA_pred)

# Calculate MSE
mse = mean_squared_error(y_test_NVDA, NVDA_pred)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test_NVDA, NVDA_pred)
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}')
# Out:
# 2/2 [==============================] - 1s 19ms/step
# RMSE: 22.74235145835354
# MAE: 19.20686516394982
# MSE: 517.2145498552753
# MAPE: 0.04216846240074226

# %%
train = NVDA[:train_size_NVDA]
valid = NVDA[train_size_NVDA:]
valid['Predictions'] = NVDA_pred
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-58-92c5930f0f89>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = NVDA_pred

# %% [markdown]
# # SO

# %%
# Ref: Lec 17

# Create a new dataframe with only the 'Close column
SO = SO.filter(['Close'])
# Convert the dataframe to a numpy array
SO_dataset = SO.values
# Train test split
train_size_SO = int(np.ceil( len(SO_dataset) * .80 ))

train_size_SO
# Out:
# 210

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
SO_scaled = scaler.fit_transform(SO_dataset)

# %%
# Create scaled training data set for SO
train_SO = SO_scaled[0:int(train_size_SO), :]
# Split the data into x_train and y_train data sets
x_train_SO = []
y_train_SO = []

for i in range(60, len(train_SO)):
    x_train_SO.append(train_SO[i-60:i, 0])
    y_train_SO.append(train_SO[i, 0])
    if i <= 61:
        print(x_train_SO)
        print(y_train_SO)
        print()

# Convert the x_train and y_train to numpy arrays
x_train_SO, y_train_SO = np.array(x_train_SO), np.array(y_train_SO)

# Reshape the data
x_train_SO = np.reshape(x_train_SO, (x_train_SO.shape[0], x_train_SO.shape[1], 1))
# Out:
# [array([0.39880046, 0.4047976 , 0.37631148, 0.38680676, 0.46176925,
#        0.46326825, 0.47676152, 0.45277355, 0.65292328, 0.66641655,
#        0.65892041, 0.60344833, 0.5329834 , 0.49400315, 0.53598196,
#        0.63043487, 0.63268365, 0.70614658, 0.74587661, 0.69940023,
#        0.73988005, 0.68140939, 0.71814085, 0.76386802, 0.60419754,
#        0.69790066, 0.68815574, 0.65892041, 0.69265331, 0.60119897,
#        0.59969997, 0.57946035, 0.4047976 , 0.3095949 , 0.35982021,
#        0.3403298 , 0.32833553, 0.37031492, 0.38980475, 0.425787  ,
#        0.3830584 , 0.40179903, 0.4902548 , 0.47226396, 0.37106413,
#        0.41829087, 0.40629659, 0.3095949 , 0.25937017, 0.3418288 ,
#        0.36056942, 0.32458775, 0.33358288, 0.26536731, 0.32308818,
#        0.24212912, 0.21889035, 0.1814091 , 0.16791583, 0.15367335])]
# [0.055472373192809066]
#
# [array([0.39880046, 0.4047976 , 0.37631148, 0.38680676, 0.46176925,
#        0.46326825, 0.47676152, 0.45277355, 0.65292328, 0.66641655,
#        0.65892041, 0.60344833, 0.5329834 , 0.49400315, 0.53598196,
#        0.63043487, 0.63268365, 0.70614658, 0.74587661, 0.69940023,
#        0.73988005, 0.68140939, 0.71814085, 0.76386802, 0.60419754,
#        0.69790066, 0.68815574, 0.65892041, 0.69265331, 0.60119897,
#        0.59969997, 0.57946035, 0.4047976 , 0.3095949 , 0.35982021,
#        0.3403298 , 0.32833553, 0.37031492, 0.38980475, 0.425787  ,
#        0.3830584 , 0.40179903, 0.4902548 , 0.47226396, 0.37106413,
#        0.41829087, 0.40629659, 0.3095949 , 0.25937017, 0.3418288 ,
#        0.36056942, 0.32458775, 0.33358288, 0.26536731, 0.32308818,
#        0.24212912, 0.21889035, 0.1814091 , 0.16791583, 0.15367335]), array([0.4047976 , 0.37631148, 0.38680676, 0.46176925, 0.46326825,
#        0.47676152, 0.45277355, 0.65292328, 0.66641655, 0.65892041,
#        0.60344833, 0.5329834 , 0.49400315, 0.53598196, 0.63043487,
#        0.63268365, 0.70614658, 0.74587661, 0.69940023, 0.73988005,
#        0.68140939, 0.71814085, 0.76386802, 0.60419754, 0.69790066,
#        0.68815574, 0.65892041, 0.69265331, 0.60119897, 0.59969997,
#        0.57946035, 0.4047976 , 0.3095949 , 0.35982021, 0.3403298 ,
#        0.32833553, 0.37031492, 0.38980475, 0.425787  , 0.3830584 ,
#        0.40179903, 0.4902548 , 0.47226396, 0.37106413, 0.41829087,
#        0.40629659, 0.3095949 , 0.25937017, 0.3418288 , 0.36056942,
#        0.32458775, 0.33358288, 0.26536731, 0.32308818, 0.24212912,
#        0.21889035, 0.1814091 , 0.16791583, 0.15367335, 0.05547237])]
# [0.055472373192809066, 0.0]

# %%
# Build model
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape= (x_train_SO.shape[1], 1)))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(15))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(x_train_SO, y_train_SO, batch_size=64, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 5s 61ms/step - loss: 0.3912
# Epoch 2/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1767
# Epoch 3/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0402
# Epoch 4/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0585
# Epoch 5/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0447
# Epoch 6/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0245
# Epoch 7/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0280
# Epoch 8/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0313
# Epoch 9/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0271
# Epoch 10/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0221
# Epoch 11/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0212
# Epoch 12/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0227
# Epoch 13/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0219
# Epoch 14/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0205
# Epoch 15/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0201
# Epoch 16/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0205
# Epoch 17/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0203
# Epoch 18/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0195
# Epoch 19/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0192
# Epoch 20/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0194
# Epoch 21/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0192
# Epoch 22/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0186
# Epoch 23/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0184
# Epoch 24/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0184
# Epoch 25/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0182
# Epoch 26/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0178
# Epoch 27/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0175
# Epoch 28/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0175
# Epoch 29/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0172
# Epoch 30/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0170
# Epoch 31/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0170
# Epoch 32/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0167
# Epoch 33/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0163
# Epoch 34/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0160
# Epoch 35/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0159
# Epoch 36/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0156
# Epoch 37/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0153
# Epoch 38/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0157
# Epoch 39/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0154
# Epoch 40/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0149
# Epoch 41/50
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0146
# Epoch 42/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0145
# Epoch 43/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0144
# Epoch 44/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0144
# Epoch 45/50
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0142
# Epoch 46/50
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0140
# Epoch 47/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0144
# Epoch 48/50
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0141
# Epoch 49/50
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0138
# Epoch 50/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0138

# %%
plt.figure(figsize=(16,6))
plt.title('SO Loss Function')
plt.plot(history.history['loss'])
plt.xlabel('Epochs', fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.show()

# %%
test_data_SO = SO_scaled[train_size_SO - 60: , :]
# Create the data sets x_test and y_test
x_test_SO = []
y_test_SO = SO_dataset[train_size_SO:, :]
for i in range(60, len(test_data_SO)):
    x_test_SO.append(test_data_SO[i-60:i, 0])

# Convert the data to a numpy array
x_test_SO = np.array(x_test_SO)

# Reshape the data
x_test_SO = np.reshape(x_test_SO, (x_test_SO.shape[0], x_test_SO.shape[1], 1))

# Get the model's predicted price values
SO_pred = model.predict(x_test_SO)
SO_pred = scaler.inverse_transform(SO_pred)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test_SO, SO_pred))

# Calculate MAE
mae = mean_absolute_error(y_test_SO, SO_pred)

# Calculate MSE
mse = mean_squared_error(y_test_SO, SO_pred)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test_SO, SO_pred)
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}')
# Out:
# 2/2 [==============================] - 1s 19ms/step
# RMSE: 1.1954511076266396
# MAE: 0.8846975473257211
# MSE: 1.4291033507257593
# MAPE: 0.013037436403950201

# %%
train_SO = SO[:train_size_SO]
valid_SO = SO[train_size_SO:]
valid_SO['Predictions'] = SO_pred

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('SO Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train_SO['Close'])
plt.plot(valid_SO[['Close', 'Predictions']])
plt.legend(['Train', 'Validation', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-65-0c4e842bec89>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_SO['Predictions'] = SO_pred
